# %% [markdown]
# ## Proceso de Data Science

# %% [markdown]
# El proceso de generación de un modelo de ML incopora numerosos y complejos pasos. Este proceso es largo y requiere de diferentes tipos de habilidades, desde ingenieria del dato hasta conocimientos de software.

# %% [markdown]
# ![Proceso%20ML2.jpg](attachment:Proceso%20ML2.jpg)

# %% [markdown]
# ### Qué hace autoML

# %% [markdown]
# Por ello, AutoML trata de automatizar gran parte de esos pasos. Concretamente, busca convinaciones de modelos y de hiperparametros que maximicen la precision de los modelos.Para ello:
#
# - AutoML ayuda a preprocesar los datos: balanceando los datos desequilibrados, imputando valores faltantes, eliminando, reemplazando o manteniendo valores atípicos, codificando categorías...
# - AutoML genera nuevas variables y selecciona las mas significativas
# - AutoML selecciona el mejor modelo entre múltiples modelos como modelos de regresión lineal, KNN, aumento de gradiente, redes neuronales...
# - AutoML ajusta los hiperparámetros del modelo elegido
# - AutoML permite crear modelos ensamblados para mejorar los resultados

# %% [markdown]
# ![autoML.png](attachment:autoML.png)

# %% [markdown]
# ## Pycaret

# %% [markdown]
# PyCaret es una herramienta de automatización del flujo de trabajo para el aprendizaje automático supervisado y no supervisado.
#
# Todos los módulos en PyCaret admiten la preparación de datos (más de 25 técnicas de preprocesamiento esenciales, ajuste automático de hiperparámetros, análisis e interpretación de modelos, selección automática de modelos, registro de experimentos y opciones de implementación en la nube)

# %% [markdown]
# ![pycaret.png](attachment:pycaret.png)

# %% [markdown]
# # Tipos de modelos de ML

# %% [markdown]
# ![it.jpg](attachment:it.jpg)

# %% [markdown]
# Fuente: https://vas3k.com/blog/machine_learning/

# %% [markdown]
# ### Clasificación

# %% [markdown]
# La clasificación es una técnica de aprendizaje automático supervisado que se utiliza para predecir las etiquetas de clase categóricas. Cuando hay unicamente dos clases se llama clasificación binaria.
# Algunos casos de uso común de clasificación son:
# 1. Predecir si un paciente tiene la enfermedad o no
# 2. Predecir el tipo de flor
# 3. Predecir si es fraude o no
#
# Es el tipo de aprendizaje supervisado en el que los datos etiquetados se utilizan para hacer predicciones en  una forma no continua .La salida de la información no siempre es continua, y  el gráfico no es lineal . En la técnica de clasificación, el algoritmo aprende de la entrada de datos que se le da y luego utiliza este aprendizaje para clasificar observaciones nuevas. Este conjunto de datos puede ser meramente bi-class, o también puede ser multi-class.
#
# Ejemplo: Uno de los ejemplos de problemas de clasificación es verificar si el correo electrónico es spam o no spam entrenando el algoritmo para diferentes palabras spam o correos electrónicos. (Vecinos más cercanos a K, SVM, Kernel, Naïve Bayes, Árbol de Decisiones, Bosque Aleatorio)

# %% [markdown]
# ### Regresión

# %% [markdown]
# La regresión es una técnica de aprendizaje automático supervisado que se utiliza para predecir un resultado continuo de la mejor manera posible dados los datos pasados ​​y sus correspondientes resultados pasados. A diferencia de la Clasificación que se usa para predecir un resultado binario como Sí o No (1 o 0), la Regresión se usa para predecir valores continuos como Ventas, Precio, cantidad, etc.

# %% [markdown]
# ### Reglas de asociación

# %% [markdown]
# Association Rule Mining es una técnica de aprendizaje automático basada en reglas para descubrir relaciones interesantes entre variables en una base de datos. Su objetivo es identificar reglas sólidas utilizando medidas de interés. Algunos casos de uso comercial comunes para la minería de reglas de asociación son:
# 1.  Análisis de la cesta de la compra para comprender los artículos que se compran juntos con frecuencia.
# 2.  Diagnóstico médico para ayudar a los médicos a determinar la probabilidad de aparición de enfermedades dados los factores y síntomas.

# %% [markdown]
# ### Clustering

# %% [markdown]
# La agrupación en clústeres es una técnica de aprendizaje automático que agrupa puntos de datos con características similares. Estas agrupaciones son útiles para explorar datos, identificar patrones y analizar un subconjunto de datos. Algunos casos de uso empresarial comunes para la agrupación en clústeres son:
# 1. Segmentación de clientes con fines de marketing.
# 2.  Análisis del comportamiento de compra del cliente para promociones y descuentos.

# %% [markdown]
# ### Detección de anomalías

# %% [markdown]
# La detección de anomalías es una técnica de aprendizaje automático que se utiliza para identificar elementos , eventos u observaciones raros mediante la verificación de filas en la tabla que difieren significativamente de la mayoría de las filas. Normalmente, los elementos anómalos se traducirán en algún tipo de problema, como fraude bancario, un defecto estructural, un problema médico o un error. Algunos casos de uso comercial comunes para la detección de anomalías son:
# 1. Detección de fraudes (tarjetas de crédito, seguros, etc.) utilizando datos financieros.
# 2. Detección de intrusiones (seguridad del sistema, malware) o supervisión de subidas y bajadas del tráfico de la red.
